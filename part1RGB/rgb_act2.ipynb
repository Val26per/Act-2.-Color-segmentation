# %%
import matplotlib.pyplot as plt
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm 
from matplotlib import colors
import cv2

img =cv2.imread('bags.png')
plt.imshow(img)
plt.show()
img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
r, g, b= cv2.split(img)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")
pixel_colors = img.reshape((np.shape(img)[0]*np.shape(img)[1],3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()
axis.scatter(r.flatten(),g.flatten(),b.flatten(),facecolors=pixel_colors,marker=".")
axis.set_xlabel("Red")
axis.set_ylabel("Green")
axis.set_zlabel("Blue")
plt.show()
light_yellow = (255, 255, 60)
dark_yellow = (150, 115, 1)

from matplotlib.colors import hsv_to_rgb
lo_square = np.full((10, 10, 3), light_yellow, dtype=np.uint8) /255.0
do_square = np.full((10, 10, 3), dark_yellow, dtype=np.uint8) /255.0
plt.subplot(1, 2, 1)
plt.imshow(lo_square)
plt.subplot(1, 2, 2)
plt.imshow(do_square)
plt.show()
mask = cv2.inRange(img,dark_yellow,light_yellow)
r1 = cv2.bitwise_and(img,img,mask=mask)
plt.subplot(1, 2, 1)
plt.imshow(mask, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(r1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm 
from matplotlib import colors
import cv2

img =cv2.imread('bags.png')
plt.imshow(img)
plt.show()
img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
r, g, b= cv2.split(img)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")
pixel_colors = img.reshape((np.shape(img)[0]*np.shape(img)[1],3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()
axis.scatter(r.flatten(),g.flatten(),b.flatten(),facecolors=pixel_colors,marker=".")
axis.set_xlabel("Red")
axis.set_ylabel("Green")
axis.set_zlabel("Blue")
plt.show()
light_green = (41, 161, 137)
dark_green = (10, 57, 54)

from matplotlib.colors import hsv_to_rgb
lo_square = np.full((10, 10, 3), light_green, dtype=np.uint8) /255.0
do_square = np.full((10, 10, 3), dark_green, dtype=np.uint8) /255.0
plt.subplot(1, 2, 1)
plt.imshow(lo_square)
plt.subplot(1, 2, 2)
plt.imshow(do_square)
plt.show()
mask = cv2.inRange(img,dark_green,light_green)
r2  = cv2.bitwise_and(img,img,mask=mask)
plt.subplot(1, 2, 1)
plt.imshow(mask, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(r2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm 
from matplotlib import colors
import cv2

img =cv2.imread('bags.png')
plt.imshow(img)
plt.show()
img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
r, g, b= cv2.split(img)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")
pixel_colors = img.reshape((np.shape(img)[0]*np.shape(img)[1],3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()
axis.scatter(r.flatten(),g.flatten(),b.flatten(),facecolors=pixel_colors,marker=".")
axis.set_xlabel("Red")
axis.set_ylabel("Green")
axis.set_zlabel("Blue")
plt.show()
light_blue = (60, 108, 218)
dark_blue = (13, 24, 100)

from matplotlib.colors import hsv_to_rgb
lo_square = np.full((10, 10, 3), light_blue, dtype=np.uint8) /255.0
do_square = np.full((10, 10, 3), dark_blue, dtype=np.uint8) /255.0
plt.subplot(1, 2, 1)
plt.imshow(lo_square)
plt.subplot(1, 2, 2)
plt.imshow(do_square)
plt.show()
mask = cv2.inRange(img,dark_blue,light_blue)
r3  = cv2.bitwise_and(img,img,mask=mask)
plt.subplot(1, 2, 1)
plt.imshow(mask, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(r3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm 
from matplotlib import colors
import cv2

img =cv2.imread('bags.png')
plt.imshow(img)
plt.show()
img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
r, g, b= cv2.split(img)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")
pixel_colors = img.reshape((np.shape(img)[0]*np.shape(img)[1],3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()
axis.scatter(r.flatten(),g.flatten(),b.flatten(),facecolors=pixel_colors,marker=".")
axis.set_xlabel("Red")
axis.set_ylabel("Green")
axis.set_zlabel("Blue")
plt.show()
light_na = (254, 138, 81)
dark_na= (200, 54, 30)

from matplotlib.colors import hsv_to_rgb
lo_square = np.full((10, 10, 3), light_na, dtype=np.uint8) /255.0
do_square = np.full((10, 10, 3), dark_na, dtype=np.uint8) /255.0
plt.subplot(1, 2, 1)
plt.imshow(lo_square)
plt.subplot(1, 2, 2)
plt.imshow(do_square)
plt.show()
mask = cv2.inRange(img,dark_na,light_na)
r4  = cv2.bitwise_and(img,img,mask=mask)
plt.subplot(1, 2, 1)
plt.imshow(mask, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(r4)
plt.show()

# %%
union= r1 + r2 + r3 + r4
plt.imshow(union)
